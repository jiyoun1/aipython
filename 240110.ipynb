# %% [markdown]
# <a href="https://colab.research.google.com/github/jiyoun1/aipython/blob/main/240110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.DataFrame([ ['Kim',27,92],
                    ['Lee', 33,98],
                    ['Park',19, 87] ])
df
# Out:
#       0   1   2
# 0   Kim  27  92
# 1   Lee  33  98
# 2  Park  19  87

# %%
import pandas as pd
df = pd.DataFrame({'name':['Kim','Lee','Park'],
                  'age':[27,33,98],
                  'score':[92,19,87]})
df
# Out:
#    name  age  score
# 0   Kim   27     92
# 1   Lee   33     19
# 2  Park   98     87

# %%
import pandas as pd

df = pd.read_csv('data.csv', encoding = 'UTF-8')
df
# Out:
#    name   age   score
# 0   Kim    27      92
# 1   Lee    33      98
# 2  Park    19      87

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv',encoding='UTF-8',delimiter ='\t')

df
# Out:
#            gameId   creationTime  gameDuration  seasonId  winner  firstBlood  \
# 0      3326086514  1504279457970          1949         9       1           2
# 1      3229566029  1497848803862          1851         9       1           1
# 2      3327363504  1504360103310          1493         9       1           2
# 3      3326856598  1504348503996          1758         9       1           1
# 4      3330080762  1504554410899          2094         9       1           2
# ...           ...            ...           ...       ...     ...         ...
# 51485  3308904636  1503076540231          1944         9       2           1
# 51486  3215685759  1496957179355          3304         9       2           1
# 51487  3322765040  1504029863961          2156         9       2           2
# 51488  3256675373  1499562036246          1475         9       2           2
# 51489  3317333020  1503612754059          1445         9       1           1
#
# ...

# %%
import pandas as pd

df = pd.read_excel('data.xlsx')

# df.head(N) # 상위 N개 항목만 출력
# df.tail(N) # 하위 N개 항목만 출력
# df.info() # 데이터 기본 정보를 출력
# Out:
# 0    구이서
# 1    김이정
# 2    오지수
# Name: 이름, dtype: object

# %%
# df['이름'] # 이름 칼럼 데이터만 불러온다
# df[['이름','성별']] # 이름과 성별 칼럼 데이터를 불러온다
# df['이름'][0:3] # 0~2까지 이름 칼럼 데이터 가져온다

# %%
# df.loc[행 번호, ['칼럼 이름']] # 레이블로 불러온다.
# df.loc[0:3,['이름']] # 0~3까지 이름 칼럼 데이터 불러온다.
# df.iloc[0:3,0:2] # loc와 달리 iloc는 종료값은 데이터 범위에 포함X

# %%
# df['국어']>=80 # 해당 칼럼 데이터에 대한 조건 연산결과 출력
# df.query('국어>=80') # 위와 같다.

# df[(df['국어']>=80) & (df['수학']>=90)]
# df.query('국어>=80 and 수학>=90')

# df[(df['국어']>=80) | (df['수학']>=90)]
# df.query('국어>=80 or 수학>=90')
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부     총점
# 9  B반  이지서  여  86.0  100.0   응시   확인  186.0

# %%
# 데이터프레임명.sort_values(by=['칼럼명'],ascending=T/F,inplace=T/F)

# df.sort_values(by=['이름']) # 이름을 기준으로 오름차순 정렬
# df.sort_values(by=['국어'],ascending=False) # 국어를 내림차순 정렬

# %%
# 데이터프레임명.index : 데이터프레임이 갖는 행 번호들
# 데이터프레임명.columns : 데이터프레임이 갖는 칼럼명들
# 데이터프레임명.size : 데이터프레임에 있는 개별 항목 개수들 (행 개수 X 칼럼 개수)

# %%
# 데이터프레임의 데이터 집계

# 데이터프레임의 전체 기본 통계 출력
# df.describe()

# 칼럼값별 데이터 개수 보기
# df['반'].value_counts()

# 개별 칼럼별의 통계값 구하기
# df['국어'].sum() # 국어점수 합
# df['국어'].mean() # 국어점수 평균

# 그룹별 통계값 구하기
# df.groupby('반').sum() # 데이터프레임에서 '반'별 데이터 합계 출력
# df.groupby('반').mean() # 데이터프레임에서 '반'별 데이터 평균 출력

# %%
# 데이터프레임의 결측치 처리
# df.isna() # 칼럼값이 없으면 True, 있으면 False
# df.isna().sum() # 칼럼별 결측치 개수 출력

# 데이터프레임에서 결측치에 값 채우기
# 데이터프레임명.fillna(채울값, inplace=True/False )
# 데이터프레임명.fillna({‘칼럼명’:’채울값’ }, inplace=True/False )
# df.fillna({'확인여부':'완료'})
# df.fillna(0)

# 데이터프레임에 결측치가 있는 데이터 삭제
# 데이터프레임명.dropna(axis=0/1, subset=[‘칼럼명’], inplace=True/False )
# axis = 0이면 결측치 있는 행, 1이면 결측치 있는 칼럼을 삭제한다
# subset으로 지정한 칼럼에 결측치 있는 데이터 삭제한다
# df2 = df.dropna(subset = ['국어']) # 국어 칼럼에 결측치있는 행 삭제
# df2
# df3 = df.dropna()
# df3

# %%
# df['총점'] = df['국어']+df['수학'] # 새 칼럼 추가
# df.drop('확인여부',axis=1) # 원본 데이터프레임은 변경하지 않고 확인여부 칼럼 삭제한 결과 출력

# 데이터프레임명.replace(바꿔야 하는 값, 바꿀 값, inplace=False/True )
# 데이터프레임명.replace({바꿔야 하는 값1:바꿀 값1, … }, inplace=False/True )
# 데이터프레임명.replace({‘칼럼명’: {바꿔야 하는 값1:바꿀 값1, … } }, inplace=False/True )

# %%
# 실습
import pandas as pd

box = pd.read_excel('BoxOffice.xlsx')
info = box.info()
print(info)

nation = box['대표국적'].value_counts()
print(nation)

UK = box[box['대표국적']=='영국']
print(UK)

box.groupby('대표국적').min(['순위'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      200 non-null    int64
#  1   영화명     200 non-null    object
#  2   개봉일     200 non-null    datetime64[ns]
#  3   매출액     200 non-null    int64
#  4   관객수     200 non-null    int64
#  5   스크린수    200 non-null    int64
#  6   상영횟수    200 non-null    int64
#  7   대표국적    200 non-null    object
#  8   국적      200 non-null    object
#  9   배급사     200 non-null    object
# dtypes: datetime64[ns](1), int64(5), object(4)
# memory usage: 15.8+ KB
# None
# 한국    116
# 미국     82
# 일본      1
# 영국      1
# Name: 대표국적, dtype: int64
#       순위     영화명        개봉일          매출액      관객수  스크린수   상영횟수 대표국적  국적  \
# 194  195  어바웃 타임 2013-12-05  25312684300  3449451   568  67267   영국  영국
#
#                      배급사
# 194  유니버설픽쳐스인터내셔널 코리아(유)
#        순위          매출액      관객수  스크린수   상영횟수
# 대표국적
# ...
